# %%
# Import the required libaries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 

y = [40, 30, 10, 50, 25, 5]
labels = ['Crime', 'Sci/fi', 'Drama', 'Comedy', 'Action', 'Docmentary']
x = np.arange(len(y))

# Create a new figure object 
plt.figure(figsize = (8,6))

# Plot vertical bars of fixed width by passing x and y values to the .bar() function
plt.bar(x, y)

# Give a title to the bar graph
plt.title('Jim\'s Video\ Library')
plt.ylabel('Number of movies')
plt.xlabel('Genres')
plt.xticks(x, labels)

plt.show()

# %%
weight = [2750, 3125, 2100, 4082, 2690, 3640, 4380, 2241, 2895, 3659]
mpg = [29, 23, 33, 28, 20, 21, 14, 25, 31, 17]

# set figure size to inches 
plt.figure(figsize = (8,6))
plt.scatter(weight, mpg, label = "weight vs. mpg")

# Set x and y axis labels 
plt.xlabel('Car weight')
plt.ylabel('Miles per Gallon')

plt.title('Consumer Cars')
plt.legend()
plt.show()

# %%
x = [43.1, 35.6, 37.5, 36.5, 45.3, 43.4, 
     40.3, 50.2, 47.3, 31.2, 42.2, 45.5, 
     30.3, 31.4, 35.6, 45.2, 54.1, 45.6, 
     36.5, 43.1]

# Plot the distogran with hist() function 
plt.hist(x, bins = 5)
plt.xlabel('Waiting Time')
plt.ylabel('Customer waiting times')
plt.show()
